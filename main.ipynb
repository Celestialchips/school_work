# %%
import numpy as np
from matplotlib import pyplot as plt

x = [-4,-3,-2,-1,0,1,2,3,4]
arr2 = []
b = float(input())

for i in x:
    k = b**i
    arr2.append(k)

plt.plot(x, arr2, marker="o", markersize=5, markerfacecolor="green")
plt.show(x, arr2)
